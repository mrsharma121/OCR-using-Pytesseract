# %%
from pdf2image import convert_from_path

# %%
import cv2

# %%
pages=convert_from_path("scan0009.pdf",500,poppler_path=r"C:\Users\Tushar\anaconda3\Library\bin\poppler-0.68.0_x86\poppler-0.68.0\bin")

# %%
#The following code is used to convert the pdf file into png format.
count=1
for page in pages:
    file_name= "page" + str(count) + ".png"
    page.save(file_name, "PNG")
    count+=1
# All the images from the pdf is saved into the directory

# %%
img=cv2.imread('page1.png')

# %%
cv2.imshow("Bank Document", img)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # The above image will pop up on the window when you run it on your system
# ## The Above Image is quite big for a common window, Therefore we will reduce the dimension of the image as much so that we can see the image properly
# #### Note We have to take care while reducing the size because I noticed too much reducing or increasing the size of the image leads to poorer results. Not sure but maybe that's related to pixels.

# %%
scale_percent=0.5
width=int(img.shape[1]*scale_percent)
height=int(img.shape[0]*scale_percent)
dimension=(width,height)
resized=cv2.resize(img,dimension,interpolation=cv2.INTER_AREA)

# %%
cv2.imshow("Bank Document", resized)
cv2.waitKey(0)
# Out:
# -1

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'
#The above code is used for setting up the path of pytesseract as the path is different from my system environment

# %% [markdown]
# The above is a Color image of the form BGR(Since openCV reads an image in BGR) It consists of an extra bit which increases its complexity

# %%
import numpy as np
np.array(resized).shape
# Out:
# (2927, 2125, 3)

# %%
#therefore we will convert the image into Grayscale
gray = cv2.cvtColor(resized, cv2.COLOR_BGR2GRAY)
#Above code is used for converting the RGB image into grayscaling

# %%
np.array(gray).shape
# Out:
# (2927, 2125)

# %%
blur = cv2.GaussianBlur(gray, (5,5), 3)
#Bluring is used to reduce the noise error in the image or for smoothing putposes
#Other types of bluring techniques are averaging,median,bilateral
#others performed poorer than gaussian filtering.

# %%
edges = cv2.Canny(gray,100,100)
#As the name suggests it's used for detecting edges in the image

# %%
thresh =cv2.adaptiveThreshold(gray,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV,11,2)
#Thresholding is a technique which is used to convert pixels of an image based on a threshold value
#Adaptive thresholding, image has different threshold value for different portion.

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (2,2))
#Kernel is basically a matrix which is used for blurring ,thresholding etc. We didnot specified the kernel above because they have their defined kernel which are mentioned in the paranthesis.
dilate = cv2.dilate(gray,kernel, iterations=1)
#Dilate adds pixels to the boundary of an image, Therefore some incomplete texts are completed

opening = cv2.morphologyEx(gray, cv2.MORPH_OPEN, kernel)
#opening is a process where erosion is followed by dilation

closing = cv2.morphologyEx(gray, cv2.MORPH_CLOSE, kernel)
#closing is reverse of opening where dilation is followed by erosion

# %%
images = {'gray': gray,
          'canny' : edges,
           'blur' : blur, 
          'adaptive thresh': thresh, 
          'opening': opening, 
          'dilate': dilate}
#Defining a dictionary

# %%
list(images.keys())
# Out:
# ['gray', 'canny', 'blur', 'adaptive thresh', 'opening', 'dilate']

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(13,13))
#This function is used to set the size of the image
ax = []

rows = 2
columns = 3
keys = list(images.keys())
for i in range(rows*columns):
    ax.append( fig.add_subplot(rows, columns, i+1) ) #This function is used to add an axis to the image and input another subplot i.e image
    ax[-1].set_title('Image Processing - ' + keys[i]) 
    plt.imshow(images[keys[i]],cmap='gray')

# %% [markdown]
# ## By default Tesseract takes English language as an input but we can also use for other languages given their file is present in the tesseract folder.
# #### Note I tried using Hindi and english both but it yielded poorer results
# ## OEM stands for OCR engine mode and here we have 2  engines i.e Legacy engine and Neural nets LSTM engine. We can use them in 4 ways.
# #### 0    Legacy engine only.
# #### 1    Neural nets LSTM engine only.
# #### 2    Legacy + LSTM engines.
# #### 3    Default, based on what is available
# ## Here I have used the last one as I don't have engines Legacy and LSTM did not performed as good as 4th option.
# ## PSM stands for Page Segmentation mode and here we have 14 options
# ### Here I have used 6 Assume a single uniform block of text.
# #### NOTE I was confused between choosing between PSM 6 and PSM 3 which is
# #### Fully automatic page segmentation, but no Orientation and script detection Therefore I performed the latter also and had gave you the choice of choosing the better one
# ##### You can play around with the tesseract on the basis of above parameters

# %%
custom_config = r'--oem 3 --psm 6'
print("TESSERACT OUTPUT FOR THE GIVEN INPUT")
print(" ")
print(pytesseract.image_to_string(dilate, config=custom_config))
# Out:
# TESSERACT OUTPUT FOR THE GIVEN INPUT
#
# | SBI Genera! Insurance Company Limited .
# IRDAI of Reg. No. 144 dated 15/12/2009 | CIN: Ué6000MH2009PLC190546 | UIN: SBG-MO-P12-57-VO Fm be $BilGeneral
# . LN S 4m ATH CE
# PRIVATE CAR/TWO WHEELER INSURANCE POLICY bene : s 110051 Ses ee
# : : : Cail (Tc ee) 1800 22 111 ] )
# feel Ueda WIA www.sbigeneral.in/download WX Sued & | www. sbigeneral.in
# Proposal Form WV Package Liability
# The queries siated below are minimum requirement to be furnished by a Proposer. The insurer may seek more information as desired for underwriting purpose la 75 eee
# \Y Pvt Car fs. Two Wheeler Proposal for uw New ead Renewal Roll Over i Used Endorsement To be filled in BLOCK LETTERS ONLY
# ince me gy Rm ma i at a ie aes aed cance a eg ar or ae t =. Agreement [ae o? So ae
# Proposal No yee | coe tt Pee | ee Ti2314'5' 61+ Code ib la .
# | | econdary Agreement
# isa —— ae 3& : tt EF ea oo nae oat -. RM Code 4 3 a 3 " Name ; Pp A < K AGE =
# Inward No 632 | ReceiptNo. 4 +2 Receipt Dae 16 Dio Zoned, f
# Break-in , T m P
# Inspection No 00 F | | | | State SP Code
# Business Sector ~~ Urban Rural | Social GSTINASDN Customer Segment Agency Banca Corporate/Broking Direct ,
# PROPOSER DETAILS ana ee SE oe a a ae
# lf you have existing relationship with SBI General Insurance then please provide Customer ID / Policy number
# Tite My. Name TUSHAR SHARMA | | ian es |
# Gender —~ Male Female Third Gender Date of Birth (31010. 34) 44% contact 9 92RZ4zi2 Bl og. | | |
# ema | | ft [ [tthe fd gen Mobile. #21 08380960 | | | |
# Occupation of the Insured L me | |
# DOB of Propeser 1 [2 re) qi g } 6 PAN No 5 Y ZT: XA 3 uy 3 Li Boot
# Address of House No Block Building |
# the Proposer 21 : : C! : “i 14 : . sete
# Locality Ss MA RIT eit oT ¥i * Street b teed oat City GHA 2 1A BA : aS
# i or eon ata) at coe 7 = : Tao a Tene j
# State UTTAR PRADESH Pincode'2 O41 9'3) coumy J NDT Al
# a er Re me
# Corporate Yes | No GSTINISON fe aes
# RISK COVERAGE DETAILS ;
# So, i ISin alial@la ; 5919 Ta) NCB onE | 1
# Period of Insurance: From Ok AY hrs of | | 20 F141 By 6 til! oe OZ eI Diz 3) 4 Povey on Expiring a ia:
# os i i OD Claim in No of Claims in }
# Previous Year Policy Period | A to | ae Expiring Policy last 3 years Amount |
# NA SOE ITN es nf cae Sacre a paeta i : - pe ec aaa
# Previous Policy No. od
# j | { | so ahr
# prea Previous Insurer veer
# Previous Insurer Lite bod { i t <3}
# Usage of Vehicle | Business ~~ Private Driver Age je \ Driver's Driving Experience 2. | Parking Type A Garage A Public Street A a ound
# ate a ee te 1 1 = F : 7
# Date of Registration | RTO RTO RTO A
# ecco SISA 2 0120) SE VITTARIP RADE ty G28 tocation LIN DIS| A ___|
# | ___ Vehicle Make, Model & Variant Month & Year of Mig. . Registration Number Engine Number Chassis Number Seating Capacity CC | FuelUsed
# Vehicie Insured Declared Value Rs Electrical Non-Electrical Trailer Value Rs. Side Car Value Rs CNG LPG Kit Rs Total IDV Rs.
# 7 i eater Rs | Acoessogs i (Two wheeler) (not provided by manufacturers)
# (A) (8) | (C) | (D) (E) | (F) (A+B+C+D+E+F) |
# Vehicle modification Yes | |.No Tea AMR ON me on ae ee
# Legal Liability to Paid Driver | No of Persons | PA To Owner Driver (Please give details of Nomination) PA to Unnamed Passenger Sum insured Rs
# Nominee Details: Name P| i YUS H GA NDH be 0B (O40 | | 2 O'D || Relation Friends
# Name of the Appointee clk aa al 5 Wk i a: ag , Appointee Relationship : > |
# (if Nominee is a Minor) \ to the Nominee
# ADD-DN COVER DETAILS ee ne Rages : i
# K Depreciation Reimbursement (Pvt Car Only) X: Cover for Consumables (Pvt Car only) VV Engine guard (Pyt Car only) Return To Invoice
# VW Protection of NCB (Cover available to protect NCB upto 50% Only as per eligibility) ~~ Basic road side assistance (Pvt Car only) X Additional road side assistance (Pvt Car only)
# XX, Loss of Personal Belongings (Pvt Car Only) Rs. — x Cover tor Key Replacement (Pvt Car only} x Inconvenience Allowance (Pvt Car Only) Rs -
# X Enhance PA Cover for insured (Owner Driver) / unnamed passengers / Paid Drivers (Pvt Car only) sum Insured per person Rs
# 'yY Hospital Cash Cover for Insured (Owner Driver) / unnamed passengers / Paid Drivers (Pvt Car only} Rs EMI Protector (Private car only)
# Ps y
# | ae Se BESTS i i ' |
# Name offinancilinstution (LTSIVIET TEISIR'ET | TP) Py Ty Py ed i oe] ie ae i a as ee eS ee
# ; ree) ett ft te ee oe r } ; als |
# teen WEIFIRIEND | |] tlt p eee ie LL) LoanAccount No. | 1/4 3 F126) 5) 4/8/42 7
# INSURED'S DECLARED VALUE (IDV) OF THE VEHICLE sae tees Bea Bes | aise Tramps coke ets
# The IDV of the vehicle will be deemed to be the sum insured for the purpose of the policy & will be fixed on the basis of the manutacturers listed selling price of the brand and adjusted for Depreciation as per schedule below
# Age of the Vehicle % of Depreciation Age of the Vehicle - % of Depreciation
# Not Exceeding 6 months 5% Exceeding 2 years bul nal exceeding 3 years 30%
# Exceeding 6 months but not Exceeding 1 year 15% Exceeding 3 years but not exceeding 4 years 40%
# Exceeding 1 year but not exceeding 2 years 20% Exceeding 4 years but no! exceeding 5 year: 50%
# VOLUNTARY DESUCTIBLE Sot Mabon, CUR et aah. | pate telat pier ek eae de MUM IE Medes ar tetera a YS, |
# Standard minimum deductible is Rs. 100/- for two wheelers, Rs. 1000 for private cars with CC upte 1500 & Rs. 2000/- for private cars above 1500 cc from each and every claim
# PRIVATE CAR DEDUCTIBLE TWO WHEELER . DEDUCTIBLE
# |_| Std min deductible Plus ‘ fis. 2500 Std min deductible Plus Rs. 500
# Sid min deductivle Plus Rs, 5000 Std min deductible Plus Rs. 750
# Std mii deductible Plus ze ___Rs. 7500 Std min deductible Plus Rs, 1000
# Std min deductible Plus Rs. 15000 Std tnin deductible Plus Rs. 1590 ie
# Sid min deductible Pius Rs. 3000 2
# hess ee a a a

# %%
print("TESSERACT OUTPUT FOR THE GIVEN INPUT")
print(" ")
print(pytesseract.image_to_string(closing, config=custom_config))
# Out:
# TESSERACT OUTPUT FOR THE GIVEN INPUT
#
# | S81 Genera! Insurance Company Limited . SBIG j
# IRDAI of fnciio Reg. No. 144 dated 15/12/2009 | CIN: U6aQ00/MH2009PLC190546 | UIN: SBG-MO-P12.57-V02-11-17 enera
# 1NS URANCE
# PRIVATE CAR/TWO WHEELER INSURANCE POLICY anieee iSanes 11701 Mies
# 5 ; : R Coll {Toll Free} 1800 22 1111 | 1 2
# feet bea1a W9A www.sbigeneral.in/download W Sueee z | www.sbigeneral.in
# Proposal Form WM Package |_| Liability
# The queries stated below are minimum requirement to be furnished by a Proposer. The insurer may seek more information as desired for underwriting purpose
# 7 Put Car |___ Two Wheeler Proposalfor: N~ New | — Renewal — | Roll Over _, Used Endorsement To be filled in BLOCK LETTERS ONLY
# FOR OFFICE USE
# a ara GATS Ee Tee. Agreement pos romncine 7 tainmsnarcmncincsonnces.o
# ProposaNo: | | | ISISSI ter —— T3456 ce JE, aaa |
# | i ee ee ! | Secondary | Agreement A
# Quote No. ote aa 236. mol SO ES er a Ee GMC WO PSS 43 43. iil Name PACK AGE =
# Inward No, j 632 | | | | ReceiptNo, 4 12 Receipt Dae 6 ZiO4Y 2 017n1 f
# Breakin ~ 2 eae narra rt acento pao
# Inspection No OOF 1) 1] APES | b_} Stota SP Code petit
# Business Sector ~~ Urban Rural | Social GSTINASDN Customer Segment Agency Banca Corporate/Broking Direct }
# PRenmSen DETAILS ee = LEPENER a a bt Sade
# if you have existing felationship with SBI General Insurance then please provide Customer ID / Policy number ! T |
# Tite My!. tam TUSHAR SHARMA SaE [| Exp |] che
# Gender ~ Male  —__ Female ThidGender Oateof Birth (3100 F4 GAA  Contactho. 9 g 234 2124] o4 Ye Fe |
# em le] TT LL Li |_|} Motieno./ FZ OS giolgeor | | |
# Occupation of the insured ae Se oy oe Om | ORG; tee | Ess: |
# DOB of Propeser 120919746 anno. SHIRA SYS A | |
# auiress ot HouseNo. ‘g [pi | Block | ] | Building i ist |
# the Propos¢r ; 21 repre tetect : C : oe 11 : ; eee
# Lom (SIMIAN! it TY! | St | es “GHAZIABAD
# sae = UTTAR PRADESH Pincode 2 O41 $3) coumy TN/D|T] Al
# — ; CN a,
# Corporate Yes | No GSTINISDN | hate
# RISK COVERAGE DETAILS ;
# ‘ a : . “ flan ao rR poem oer NCB on Exnir . °
# Period of insurance: From OKAY. hrs of hizo Fd Sy 6 till aie 3 O'2, 0/212 31114 Py on Expiring pelo
# > T i i ig | aim in No of Claims ir f }
# Previous: Neat Poloy.Perlod LU | UM ite | Ct Pome ee Expiring Policy tast 3 ey - Amount Si
# eae eS ee ee Nanetrs ae = mae our Ban eel =o ak
# pooped Ho: L i bist sed CGY ee Previous Insurer oe ee
# Previous Insurer lh ae ‘ |e crs SPRL IE { ! L | |
# Pragati aL | la ET ee Nea Sipeione | |) Pain te A Gomme FR pen - Fh) Brooune
# DaeotRegstaton (T 2) 22020 SM urTARPRADE [fPG2B in IM DITIA | |
# | Vehicle Make, Model & Variant Month & Year of Mtg. i Registration Number Engine Number | Chassis Number Seating Capacity CC | FuelUsed |
# Vehicie insured Declared Value Rs. Electrical Non-Electrical Trailer Value Rs. Side Car Value Rs. | || GN LPG Kit Rs. Total IDV Rs.
# ee eS iene the ascii {Two wheeler) (not provided by manufactures) aa
# (A) (B) | (C) | (D) {E) | (F} (A+B4+C4+D+E+F) | |
# Vehicle modification | Yes | | No OS a a na ee a I
# Legai Liability to Paid Driver | No of Persons | PA To Owner Daver (Please give details of Nomination) i PA to Unnamed Passenger Sum insured Rs
# Nominee Details: Name PITYUS Hn GAWD re ae 008 104% O 112 O'] | Relation Friends |
# Name of the Appointee Ceo pee ot ee ; ama Bram lie 9 Appointee Relationship = =
# (if Nominee is a Minor) a ! peel i : to the Nominee .
# ADD-ON COVER DETAILS : ye : ng 1h ‘ C \s
# K Depreciation Reimbursement (Pvt Car Only) x Cover for Consumables (Pvt Car only) WU Engine guard (Pyt Car only) Return To Invoice
# VW Protection of NCB (Cover available to protect NCB upto 50% Only as per eligibility) ‘Basic road side assistance (Pvt Car only) x Additional read side assistance (Pvt Car only)
# XX Loss of Personal Belongings (Pvt Car Only) Rs. x Cover for Key Replacement (Pvt Car only) XX! inconvenience Allowance (Pvt Car Only) Rs. "
# X_ Enhance PA Cover for insured (Owner Driver) / unnamed passengers / Paid Drivers (Pvt Car only} sum insured per person As
# Lx Hospital Cash Cover tor Insured (Owner Driver) / unnamed passengers / Paid Drivers (Pvt Car only) Rs EMI Protector (Private car only)
# a HYPOTHECATION G HIRE PURCHASE | LEASE PURCHASE " be |
# se: Pet LIVE LY €E We ei se: - a a ry —
# brnen WEIEIKWEN DO | |) tf | | | | || Loam Accounno. | 1/413) 7/2 6/5/48 9
# INSURED'S DECLARED VALUE (IDV) OF THE VEHICLE pep imal ete i a us
# The IDV of the vehicle will be deemed to be the sum insured for the purpose of the policy & will be fixed on the basis of the manufacturer's listed selling price of the brand and adjusted for Depreciation as per schedule below
# |_ Age ofthe Vehicle | %ot Depreciation Age of ihe Vehicle < i % of Depreciation |
# Not Exceeding 6 months : 5% Exceeding 2 years bul nol exceeding 3 years 30% |
# Exceeding 6 months but not Excdeding 1 year ! 15% Exceeding 3 years but not exceeding 4 years 40%
# Exceeding 1 year but not exceeding 2 years ; 20% Exceeding 4 years but no! exceeding 5 years 50%
# VOLUNTARY DEBLETIBLE Te he ae Rot Aen ans ie MRE Pete Mole eiciea Toe |
# Standard minimum deductible is Rs. 100/- for two wheelers, Rs. 1900 for srivate cars with CC upte 1509 & Rs. 2000/- tor private cars above 1500 cc trom each avid every claim
# .___ PRIVATE CAR DEDUCTIBLE TWO WHEELER ? DEOUCTIBLE
# || Std min deductible Plus ; fis, 2500 Std min deductible Plus Rs. 500
# |_| Std rnin: deductible Plus | Rs. 5000 Std min deductible Plus * Rs. 750
# Sid min deductible Plus = ae De ____Rs. 7500 Std min deductible Plus Rs, 1000
# Std min deductible Plus Rs. 15000 Std min deductible Plus Rs. 1990 mi
# Std min deductible Plus Rs. 3000 ,
# hciassia es ee eee

# %%
print("TESSERACT OUTPUT FOR THE GIVEN INPUT")
print(" ")
print(pytesseract.image_to_string(opening, config=custom_config))
# Out:
# TESSERACT OUTPUT FOR THE GIVEN INPUT
#
# ' SBI Genera! Insurance Company Limited . SBIG j
# IRDAI of {ncio Reg. No. 144 dated 15/12/2009. | CIN: U6e000MH2009PLC190546 | UIN: SBG-MO-P12-57-V02-1 1-12 ‘> enera
# . in S$ U R ACN CE
# PRIVATE CAR/TWO WHEELER INSURANCE POLICY er ere TS
# a ‘ : Coll (ioll Free 44 |
# feel Weald W9A www.sbigeneral.in/download W Saeed z | www.sbigeneral.in
# Proposal Form W Package | | Liability
# The queries stated below are minimum requirement to be furnished by a Proposer. The insurer may seek more intormation as desired for underwriting purpose
# V7 PvtCar | | Two Wheeler Proposalfor: NX“ New | | Renewal | Roll Over |_| Used |__| Endorsement To be filled in BLOCK LETTERS ONLY
# Sew. fo! RR Rice Sei eee aia age Ziq Agreement fata -| 1 1 YY
# ProposaNo. = | | | ISIMSiG | | tt te ttt = — 12345 6 F cote LE. Sa ee
# ] = Va fe a Pa Tt econdary | Agreement AG
# uote Ny: ESS. i BESERSESSEeel a RM Code 4 = 3% 43 = Name PACKAGE —
# Inward No. tT] 632 | [J Receipt No. [414 2 Receipt Date [6 2/04) 2/ 0/2/12 :
# ensli . : er a ee + emma wee . en 4
# Inspection No 1 9 0 ib a Lt | 1 hawdaat ack iol State SP Code Sats ON i
# Business Sector ~~ Urban Rural | Social GSTINASON i Customer Segment Agency Banca | Corporate/Broking | Direct
# PROPOSER DETAILS Bie ah ag |
# ff you have eaisting relationship with SBI General Insurance then please provide Customer ID / Policy number | |
# — 4 rs _ - ee ee ee ee ee ee ae
# Tite My |) wm TIUSIHAR SHAR MAL [| [i [sbi Tele lepetey Tt)
# Gender ~ Mae = =—__ Female _| Third Gender Date of Birth [3/010 | 714 QQ Contact tio. 938s Rice irc
# enw i tT Titi ttt Tpit TP tT Tre ee TTT | Moone aio sigiol4iéor TT 7)
# Ocewpatonoftnensved =| | | TTP Te)
# 0B of Propese 120491436 avo Si 4 TRA B4 ZH | |
# Address of House No. (Eke i | Block (¢.| ] i Building | P| oe a |
# the Propostr Ziti eet ¢! : : : ia SS ee rear
# Loree is MART iti TY) = Cs Shana: stom 2 nearer ane _ rene ap eee oy a a AZIA & ADB sat
# sue = UTTAR PRADESH | Pin code 2 OH 1° $3) coumy TN D|T Al
# Corporate Yes__| No estiwison [
# RISK COVERAGE DETAILS : :
# ‘ : A) A 24. j 621122 21u NCB Expiri | ,
# Period of Insurance: From OK AY) | sot ‘1210 #1346 | till — 0'2)4 [22 sivi4y Mey on Expiring [| }*
# : a ‘i 1 ee pew a j ] aim in Ten No of Claims in ‘a -
# Previous Year Policy Period 0 + Lil ea 2 es fla tv Sc i ae ik Expy Pokey last 3 years Amount =
# o sie, [ T ob Te ee ee oe i SS 2 as a eee ee lame of ‘tr <> Oa a ee H sas Co aad ik ] say |
# Previous Policy No. | ae ek os ek {SUE Se Previous Insurer 1 iL ine
# Address of i 4 am hae Neie cae| rater ae ess
# Previous Insurer t a: ES a A “I 1 |e ace Sie, ies Ee BER Se ! Lol = H pA |
# Usage of Vehicle a seed du ud _ Private Driver Age \2| i Driver's Driving Experience 2, | Parking Type A. Garage Ay Pubic Street A Eeesound
# istrati 1121 7 | RO Dry ARIPO RA RTO | 2 RTO TIRATA
# dang Regeiaion VIS 2121012/0; SE VITTIARIPR ADE  fiGz/ Bi | ivewon ZIN-DIT|A__|
# | __ Vehicle Make, Model & Variant | Month & Year of Mtg. | Registration Number Engine Number | Chassis Number Seating Capacity CC Fuel Used |
# OR eae rt BATE Rs 3.2 De oe ee Ee ae eS ee eee
# | _ Vehicle insured Declared Value Rs. Electrical Non-Electrical Trailer Value Rs. Side Car Value Rs. || GNG LPG Kit Rs. Total IDV Rs.
# ne ee Metre cit Oni {Two wheeler) (not provided by manufacturers) a
# (A) (8) | €) | (D) (E) | (F) (A+B4+C+D+E+F) |
# |
# Vehicle mouitication Yes | | No SS aaa Se er Ske =
# | Legai Liability to Paid Driver | 5 No of Persons , PA To Owner Daver (Please give details of Nomination) | PA to Unnamed Passenger Sum Insured Rs
# Nominee Oeuis:Name = PIT YU SH GAWD AD | 08 O4O | 2O2| Fwiton Fyemads |
# Name of the Appointee ‘ee ee as <i a se ror. te T Appointee Relationship matinee =
# {If Nominee is. a Minor) i Load ! , i } Sew. ae: TE to the Nominee
# ADD-ON COVER DETAILS ee 2% ante ee : ; is
# x Depreciation Reimbursement (Pvt Car Only) ix Cover for Consumables (Pvt Car only) v Engine guard (Pvt Car only) Return To Invoice
# V Protection of NCB (Cover available to protect NCB upto 50% Only as per eligibility) | Basic road side assistance (Pvt Car only) x Additional road side assistance (Pvt Car only)
# XK Loss of Personal Belongings (Pvt Car Only) Rs, —_________ i x Cover for Key Replacement (Pvt Car only) x inconvenience Allowance (Pvt Car Only) Rs. a —_
# x Enhance PA Cover for Insured (Owner Driver) / unnarned passengers / Paid Drivers (Pvt Car only) suri Insured per person Rs.
# x Hospital Cash Cover tor Insured (Owner Driver) / unnamed passengers / Paid Drivers (Pvt Car only) Rs. f _| EMI Protector (Private car only)
# WB HYPOTHECATION (4 HIREPURCHASE LEASE PURCHASE i a :
# ; een ee en
# Name fFnanciveman (LTTE! (cise; TT Tt ttt iti titi yt] ci oeatheee ee
# brnen WEEKEND | ||| ft | | | | boanAccountno. | 14/3 7126151418 12 Z|
# INSURED'S DECLARED VALUE (IDV) OF THE VEHICLE oe : : ee 1 } ‘
# The IDV of the vehicle will be deemed to be the sum insured for the purpose of the policy & will be fixed on the bas's of ihe manufacturers listed selling price of the brand and adjusted for Depreciation as per schedule below _
# __Age of the Vehicle. | %of Depreciation Age of the Vehicle * 1 % of Depreciation |
# Not Exceeding 6 months ! 5% Exceeding 2 years but nol exceeding 3 years 30% |
# Exceeding 6 months but not Excieding 1 year 1 15% Exceeding 3 years but not exceeding 4 years 40% |
# Exceeding 1 year butnot exceeding 2 years : } 20% Exceeding 4 years but not exceeding 5 yea s Lett: 0% =
# VOLUNTARY DEBUICTIBLE RES NAG Ba a 1h iS RRO he ee a a |
# Standard m:nimum deductible is Rs. 100/- for two wheelers, Rs. 1000 for private cars with CC upte 1500 & Rs. 2000/- tor private cars above 1500 cc trom each aiid every claim : xe
# scree PRIVATE CAR _ sc sak DEDUCTIBLE TWO WHEELER - DEDUCTIBLE
# Lo Stdimin deauetible Plus i ___ fis. 2500_ /___ Std min deductible Plus ____ Rs. 500
# \__.' Sid mini deductible Plus | Rs, 5000 ~~ Std min deductible Plus Rs. 750
# | StdemindeductiblePlus 7500 Std min deductible Plus : Rs, 1000
# '__| Std min deductible Plus Rs. 15000 Std min deductible Plus 8s. 1500, i
# Std min deductible Plus Rs. 3000
# ree eee

# %%
from pytesseract import Output
d = pytesseract.image_to_data(dilate, output_type=Output.DICT)
d.keys()
# Out:
# dict_keys(['level', 'page_num', 'block_num', 'par_num', 'line_num', 'word_num', 'left', 'top', 'width', 'height', 'conf', 'text'])

# %% [markdown]
# ## You can also see the boxes which the tesseract is considering from printing by running the following code

# %%
n_boxes = len(d['text'])
for i in range(n_boxes):
    if int(d['conf'][i]) > 60:
        (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
        img = cv2.rectangle(dilate, (x, y), (x + w, y + h), (0, 255, 0), 2)

cv2.imshow('img', dilate)
cv2.waitKey(0)
# Out:
# -1
